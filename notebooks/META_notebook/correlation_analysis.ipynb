# %%
import pandas as pd

# Load the data
df = pd.read_csv(r'C:\Users\Yibabe\Desktop\kifiyaweek1\data\merged\META_news_with_sentiment.csv')

# %%
df.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2009-04-27 00:00:00+00:00   9.572619   9.700889   9.533018   9.612719
# 1  2009-04-27 00:00:00+00:00   9.572619   9.700889   9.533018   9.612719
# 2  2009-04-29 00:00:00+00:00   9.613217   9.837377   9.609730   9.750204
# 3  2009-05-22 00:00:00+00:00   9.879469   9.929034   9.763404   9.800764
# 4  2009-05-27 00:00:00+00:00  10.103131  10.258050  10.082458  10.101138
#
#    Adj Close     Volume  Dividends  Stock Splits  \
# 0   9.601792   91967429        0.0           0.0
# 1   9.601792   91967429        0.0           0.0
# 2   9.739121  144941247        0.0           0.0
# 3   9.789624   69001669        0.0           0.0
# 4  10.089657  121826932        0.0           0.0
#
#                                             headline  \
# 0      Update on the Luxury Sector: 2nd Quarter 2009
# 1      Update on the Luxury Sector: 2nd Quarter 2009
# 2                             Going Against the Herd
# 3  Charles Sizemore Radio Interview Saturday Morning
# 4  MRM a $15-$20+ stock - FIT new information - J...
#
#                                                  url  \
# 0  https://www.benzinga.com/charles-lewis-sizemor...
# 1  https://www.benzinga.com/charles-lewis-sizemor...
# 2  https://www.benzinga.com/charles-lewis-sizemor...
# 3  https://www.benzinga.com/11218/charles-sizemor...
# 4  https://www.benzinga.com/superman/2009/5/27/mr...
#
#                     publisher stock day_of_week  polarity  subjectivity  \
# 0  Charles Lewis Sizemore CFA    FT      Monday  0.000000      0.000000
# 1  Charles Lewis Sizemore CFA     Y      Monday  0.000000      0.000000
# 2  Charles Lewis Sizemore CFA     A   Wednesday  0.000000      0.000000
# 3  Charles Lewis Sizemore CFA    AM      Friday  0.000000      0.000000
# 4                    superman   EPS   Wednesday  0.268182      0.427273
#
#   sentiment
# 0   neutral
# 1   neutral
# 2   neutral
# 3   neutral
# 4  positive

# %%
# Calculate sentiment intensity based on the 'polarity' column
df['Sentiment_Intensity'] = df['polarity']

# Check the updated DataFrame
df[['Date', 'headline', 'polarity', 'Sentiment_Intensity']].head(10)
# Out:
#                         Date  \
# 0  2009-04-27 00:00:00+00:00
# 1  2009-04-27 00:00:00+00:00
# 2  2009-04-29 00:00:00+00:00
# 3  2009-05-22 00:00:00+00:00
# 4  2009-05-27 00:00:00+00:00
# 5  2009-05-27 00:00:00+00:00
# 6  2009-05-27 00:00:00+00:00
# 7  2009-05-27 00:00:00+00:00
# 8  2009-05-27 00:00:00+00:00
# 9  2009-05-27 00:00:00+00:00
#
#                                             headline  polarity  \
# 0      Update on the Luxury Sector: 2nd Quarter 2009  0.000000
# 1      Update on the Luxury Sector: 2nd Quarter 2009  0.000000
# 2                             Going Against the Herd  0.000000
# 3  Charles Sizemore Radio Interview Saturday Morning  0.000000
# 4  MRM a $15-$20+ stock - FIT new information - J...  0.268182
# 5  JVA perks to 39% gain, SMCG ready, MRM to cont...  0.200000
# 6  JVA perks to 39% gain, SMCG ready, MRM to cont...  0.200000
# 7  MRM a $15-$20+ stock - FIT new information - J...  0.268182
# 8  JVA perks to 39% gain, SMCG ready, MRM to cont...  0.200000
# 9  MRM a $15-$20+ stock - FIT new information - J...  0.268182
#
#    Sentiment_Intensity
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.268182
# 5             0.200000
# 6             0.200000
# 7             0.268182
# 8             0.200000
# 9             0.268182

# %%
# Ensure the 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the DataFrame by date
df = df.sort_values(by='Date')

# Calculate the daily stock returns as the percentage change in 'Close' prices
df['Daily_Stock_Return'] = df['Close'].pct_change() * 100

# %%
# Check the updated DataFrame
df[['Date', 'Close', 'Daily_Stock_Return']].head()
# Out:
#                        Date      Close  Daily_Stock_Return
# 0 2009-04-27 00:00:00+00:00   9.612719                 NaN
# 1 2009-04-27 00:00:00+00:00   9.612719            0.000000
# 2 2009-04-29 00:00:00+00:00   9.750204            1.430246
# 3 2009-05-22 00:00:00+00:00   9.800764            0.518553
# 4 2009-05-27 00:00:00+00:00  10.101138            3.064802

# %%
# Group by 'Date' and calculate the average sentiment intensity for each day
daily_sentiment = df.groupby('Date')['Sentiment_Intensity'].mean().reset_index()

# Merge with the daily stock return data
daily_data = df[['Date', 'Daily_Stock_Return']].drop_duplicates()
daily_data = daily_data.merge(daily_sentiment, on='Date')
# Check the merged DataFrame
daily_data.head()
# Out:
#                        Date  Daily_Stock_Return  Sentiment_Intensity
# 0 2009-04-27 00:00:00+00:00                 NaN             0.000000
# 1 2009-04-27 00:00:00+00:00            0.000000             0.000000
# 2 2009-04-29 00:00:00+00:00            1.430246             0.000000
# 3 2009-05-22 00:00:00+00:00            0.518553             0.000000
# 4 2009-05-27 00:00:00+00:00            3.064802             0.234091

# %%
# Compute the correlation coefficient between sentiment intensity and stock returns
correlation = daily_data['Sentiment_Intensity'].corr(daily_data['Daily_Stock_Return'])

# %%
print(f'Correlation between sentiment intensity and stock returns: {correlation}')
# Out:
# Correlation between sentiment intensity and stock returns: 0.023923932787174074
