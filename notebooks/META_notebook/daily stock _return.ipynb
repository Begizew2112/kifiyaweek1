# %%
import pandas as pd
# Load the merged data into a DataFrame
df = pd.read_csv(r'C:\Users\Yibabe\Desktop\kifiyaweek1\data\merged\META_merged_data.csv')

# %%
df.head()
# Out:
#                          Date  Open       High        Low  Close  Adj Close  \
# 363 2012-12-12 00:00:00+00:00  28.0  28.139999  27.370001  27.58  27.523441
# 362 2012-12-12 00:00:00+00:00  28.0  28.139999  27.370001  27.58  27.523441
# 361 2012-12-12 00:00:00+00:00  28.0  28.139999  27.370001  27.58  27.523441
# 360 2012-12-12 00:00:00+00:00  28.0  28.139999  27.370001  27.58  27.523441
# 359 2012-12-12 00:00:00+00:00  28.0  28.139999  27.370001  27.58  27.523441
#
#        Volume  Dividends  Stock Splits  \
# 363  46704200        0.0           0.0
# 362  46704200        0.0           0.0
# 361  46704200        0.0           0.0
# 360  46704200        0.0           0.0
# 359  46704200        0.0           0.0
#
#                                               headline  \
# 363  Bank of America Merrill Lynch Reiterates Buy R...
# 362  BMO Capital Maintains Outperform on Newell Rub...
# 361  UPDATE: BMO Capital Markets Reiterates Outperf...
# 360       Deutsche Bank Downgrades Novartis AG to Hold
# 359                          Benzinga's Top Downgrades
#
#                                                    url       publisher stock  \
# 363  https://www.benzinga.com/analyst-ratings/analy...  Dwight Einhorn   NWS
# 362  https://www.benzinga.com/news/12/12/3166103/bm...      Juan Lopez   NWL
# 361  https://www.benzinga.com/analyst-ratings/analy...  Dwight Einhorn   NWL
# 360  https://www.benzinga.com/news/12/12/3165828/de...      Juan Lopez   NVS
# 359  https://www.benzinga.com/analyst-ratings/downg...      Lisa Levin   NVS
#
#     day_of_week  Daily Return  Daily Return (%)
# 363   Wednesday           0.0               0.0
# 362   Wednesday           0.0               0.0
# 361   Wednesday           0.0               0.0
# 360   Wednesday           0.0               0.0
# 359   Wednesday           0.0               0.0

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the DataFrame by date
df = df.sort_values(by='Date')

# Ensure 'Close' column is in numeric format
df['Close'] = pd.to_numeric(df['Close'], errors='coerce')

# %%
# Calculate daily returns
df['Daily Return'] = df['Close'].pct_change()

# Convert daily returns to percentage
df['Daily Return (%)'] = df['Daily Return'] * 100

# %%
# Drop rows with NaN values in 'Daily Return'
df = df.dropna(subset=['Daily Return'])

# %%
# Save the DataFrame with daily returns to a new CSV file
df.to_csv(r'C:\Users\Yibabe\Desktop\kifiyaweek1\data\merged\META_merged_data_with_returns.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Plot daily returns
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Daily Return (%)'], label='Daily Return (%)', color='blue')
plt.title('Daily Stock Returns')
plt.xlabel('Date')
plt.ylabel('Daily Return (%)')
plt.legend()
plt.grid(True)
plt.show()
